# %%
import torch

# %%
a = torch.tensor([[1, 2, 3], [10, 20, 30], [100, 200, 300]])
b = a.sum(dim=1, keepdim=True)


a/b
# Out:
# tensor([[0.1667, 0.3333, 0.5000],
#         [0.1667, 0.3333, 0.5000],
#         [0.1667, 0.3333, 0.5000]])

# %%
W = torch.randn((20, 20))

# %%
W[2,:]
W[2]
# Out:
# tensor([ 0.4284,  1.4310,  0.8577, -1.7528,  0.7669,  1.7614,  0.0477,  1.0006,
#          0.1468, -0.5108, -0.8434, -0.0940,  1.5109,  1.9818, -0.1025,  0.7028,
#         -0.2055,  0.4316, -0.3483, -1.4526])

# %%
word = ['a', 'b', 'c', 'd']
word[:5]
# Out:
# ['a', 'b', 'c', 'd']
