# %%
import torch

# %%
a = torch.tensor([[1, 2, 3], [10, 20, 30], [100, 200, 300]])
b = torch.tensor([4, 5 ,6])

a + b
# Out:
# tensor([[  5,   7,   9],
#         [ 14,  25,  36],
#         [104, 205, 306]])

# %%
A = torch.tensor([[[1], [2], [3]]]) 
B = torch.tensor([[10, 20, 30, 40], [10, 20, 30, 40], [10, 20, 30, 40]])
B.sum(0)
# Out:
# tensor([ 30,  60,  90, 120])
